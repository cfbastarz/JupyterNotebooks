# %%
from xgrads import open_mfdataset

# %%
# %%time

gl_rmse = open_mfdataset('gl/RMSE*_20230216002023030300F.ctl', parallel=True)

# %%
gl_rmse
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 36, lat: 401, lon: 901)
# Coordinates:
#   * time     (time) datetime64[ns] 2023-02-16 2023-02-17 ... 2023-02-27
#   * lat      (lat) float32 -80.0 -79.6 -79.2 -78.8 -78.4 ... 78.8 79.2 79.6 80.0
#   * lon      (lon) float32 0.0 0.4 0.8 1.2 1.6 ... 358.4 358.8 359.2 359.6 360.0
# Data variables: (12/19)
#     vtmp925  (time, lat, lon) float32 dask.array<chunksize=(1, 401, 901), meta=np.ndarray>
#     vtmp850  (time, lat, lon) float32 dask.array<chunksize=(1, 401, 901), meta=np.ndarray>
#     vtmp500  (time, lat, lon) float32 dask.array<chunksize=(1, 401, 901), meta=np.ndarray>
#     temp850  (time, lat, lon) float32 dask.array<chunksize=(1, 401, 901), meta=np.ndarray>
#     temp500  (time, lat, lon) float32 dask.array<chunksize=(1, 401, 901), meta=np.ndarray>
#     temp250  (time, lat, lon) float32 dask.array<chunksize=(1, 401, 901), meta=np.ndarray>
#     ...       ...
# ...

# %%
dset_gl_rmse

# %%
dset_gl_rmse.vtmp925.isel(time=0).plot()

# %%
# %%time

df_gl_rmse = dset_gl_rmse.to_dataframe()

# %%
df_gl_rmse

# %%
df_gl_rmse.to_csv('RMSEBAMH_20230216002023030300F-gl.csv')
