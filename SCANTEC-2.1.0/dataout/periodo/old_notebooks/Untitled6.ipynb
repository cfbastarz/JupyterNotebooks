# %%
import panel as pn
pn.extension()
import random

rcolor = lambda: "#%06x" % random.randint(0, 0xFFFFFF)

box = pn.GridBox(*[pn.pane.HTML(styles=dict(background=rcolor()), width=50, height=50) for i in range(24)], ncols=6)
box
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# WARNING:param.HTML00156: Setting non-parameter attribute styles={'background': '#0d1fb0'} using a mechanism intended only for parameters
# WARNING:param.HTML00158: Setting non-parameter attribute styles={'background': '#7448a3'} using a mechanism intended only for parameters
# WARNING:param.HTML00160: Setting non-parameter attribute styles={'background': '#0e661e'} using a mechanism intended only for parameters
# WARNING:param.HTML00162: Setting non-parameter attribute styles={'background': '#b09b4d'} using a mechanism intended only for parameters
# WARNING:param.HTML00164: Setting non-parameter attribute styles={'background': '#7c719c'} using a mechanism intended only for parameters
# WARNING:param.HTML00166: Setting non-parameter attribute styles={'background': '#fda535'} using a mechanism intended only for parameters
# WARNING:param.HTML00168: Setting non-parameter attribute styles={'background': '#04e0b7'} using a mechanism intended only for parameters
# WARNING:param.HTML00170: Setting non-parameter attribute styles={'background': '#4b20d5'} using a mechanism intended only for parameters
# WARNING:param.HTML00172: Setting non-parameter attribute styles={'background': '#045f26'} using a mechanism intended only for parameters
# WARNING:param.HTML00174: Setting non-parameter attribute styles={'background': '#b3d59d'} using a mechanism intended only for parameters
# WARNING:param.HTML00176: Setting non-parameter attribute styles={'background': '#2edff8'} using a mechanism intended only for parameters
# WARNING:param.HTML00178: Setting non-parameter attribute styles={'background': '#b28f54'} using a mechanism intended only for parameters
# WARNING:param.HTML00180: Setting non-parameter attribute styles={'background': '#0992c6'} using a mechanism intended only for parameters
# WARNING:param.HTML00182: Setting non-parameter attribute styles={'background': '#7105aa'} using a mechanism intended only for parameters
# WARNING:param.HTML00184: Setting non-parameter attribute styles={'background': '#3cc54c'} using a mechanism intended only for parameters
# WARNING:param.HTML00186: Setting non-parameter attribute styles={'background': '#cabd72'} using a mechanism intended only for parameters
# WARNING:param.HTML00188: Setting non-parameter attribute styles={'background': '#2517e2'} using a mechanism intended only for parameters
# WARNING:param.HTML00190: Setting non-parameter attribute styles={'background': '#a9e90d'} using a mechanism intended only for parameters
# WARNING:param.HTML00192: Setting non-parameter attribute styles={'background': '#2a05ec'} using a mechanism intended only for parameters
# WARNING:param.HTML00194: Setting non-parameter attribute styles={'background': '#f61d6d'} using a mechanism intended only for parameters
# WARNING:param.HTML00196: Setting non-parameter attribute styles={'background': '#34c4e7'} using a mechanism intended only for parameters
# WARNING:param.HTML00198: Setting non-parameter attribute styles={'background': '#12339e'} using a mechanism intended only for parameters
# WARNING:param.HTML00200: Setting non-parameter attribute styles={'background': '#0e7d6d'} using a mechanism intended only for parameters
# WARNING:param.HTML00202: Setting non-parameter attribute styles={'background': '#574729'} using a mechanism intended only for parameters
# GridBox(ncols=6)
#     [0] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [1] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [2] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [3] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [4] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [5] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [6] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [7] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [8] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [9] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [10] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [11] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [12] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [13] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [14] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [15] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [16] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [17] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [18] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [19] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [20] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [21] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [22] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [23] HTML(None, height=50, sizing_mode='fixed', width=50)

# %%
box
# Out:
# GridBox(ncols=6)
#     [0] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [1] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [2] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [3] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [4] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [5] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [6] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [7] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [8] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [9] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [10] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [11] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [12] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [13] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [14] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [15] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [16] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [17] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [18] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [19] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [20] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [21] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [22] HTML(None, height=50, sizing_mode='fixed', width=50)
#     [23] HTML(None, height=50, sizing_mode='fixed', width=50)
